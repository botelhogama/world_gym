# %%
import requests
import pandas as pd
import json
import os

# %%
class GetClientData:
    def __init__(self, endpoint="/api/v1/members"):
        self.base_url = "https://evo-integracao.w12app.com.br/"
        self.user = "worldgym"
        self.password = "44D6E01E-6DFF-4E0F-A787-73F0036496F1"
        self.endpoint = endpoint
        self.params = {
            "take": 25,
            "skip": 0,
            "onlyPersonal": False,
            "showActivityData": True
        }
        self.data = []

    def make_api_request(self):
        try:
            while True:
                response = requests.get(self.base_url + self.endpoint, auth=(self.user, self.password), params=self.params)
                response.raise_for_status()

                # Debugging Point: Print the status code
                print(f"Status Code: {response.status_code}")

                current_data = response.json()
                self.data.extend(current_data)

                # Debugging Point: Print the number of records fetched so far
                print(f"Total Records So Far: {len(self.data)}")

                if len(current_data) < self.params["take"]:
                    break
                self.params["skip"] += self.params["take"]
                print(f"Retrieved {self.params['skip']} records so far")

        except requests.exceptions.RequestException as e:
            print("Error:", e)

    def retrieve_data(self, use_cache=True):
        cache_file_path = f"C:/Users/Pichau/PycharmProjects/worldgym/data/{self.endpoint.replace('/','_')}_cache.json"

        if use_cache and os.path.exists(cache_file_path):
            with open(cache_file_path, "r") as file:
                self.data = json.load(file)
            print(f"Data loaded from cache for endpoint: {self.endpoint}")
        else:
            self.make_api_request()
            print(f"Total records retrieved: {len(self.data)}")
            os.makedirs(os.path.dirname(cache_file_path), exist_ok=True)
            with open(cache_file_path, "w") as file:
                json.dump(self.data, file)
            print("Data cached.")

        df = pd.DataFrame(self.data)
        return df

# Forcing the code to fetch fresh data by setting use_cache to False
membership_data = GetClientData(endpoint="/api/v1/membermembership")
df_membership = membership_data.retrieve_data(use_cache=False)
print(f"df_membership shape is : {df_membership.shape}")
# Out:
# Status Code: 200
# Total Records So Far: 25
# Retrieved 25 records so far
# Status Code: 200
# Total Records So Far: 50
# Retrieved 50 records so far
# Status Code: 200
# Total Records So Far: 75
# Retrieved 75 records so far
# Status Code: 200
# Total Records So Far: 100
# Retrieved 100 records so far
# Status Code: 200
# Total Records So Far: 125
# Retrieved 125 records so far
# Status Code: 200
# Total Records So Far: 150
# Retrieved 150 records so far
# Status Code: 200
# Total Records So Far: 175
# Retrieved 175 records so far
# Status Code: 200
# Total Records So Far: 200
# Retrieved 200 records so far
# Status Code: 200
# Total Records So Far: 225
# Retrieved 225 records so far
# Status Code: 200
# Total Records So Far: 250
# Retrieved 250 records so far
# Status Code: 200
# Total Records So Far: 275
# Retrieved 275 records so far
# Status Code: 200
# Total Records So Far: 300
# Retrieved 300 records so far
# Status Code: 200
# Total Records So Far: 325
# Retrieved 325 records so far
# Status Code: 200
# Total Records So Far: 350
# Retrieved 350 records so far
# Status Code: 200
# Total Records So Far: 375
# Retrieved 375 records so far
# Status Code: 200
# Total Records So Far: 400
# Retrieved 400 records so far
# Status Code: 200
# Total Records So Far: 425
# Retrieved 425 records so far
# Status Code: 200
# Total Records So Far: 450
# Retrieved 450 records so far
# Status Code: 200
# Total Records So Far: 475
# Retrieved 475 records so far
# Status Code: 200
# Total Records So Far: 500
# Retrieved 500 records so far
# Status Code: 200
# Total Records So Far: 525
# Retrieved 525 records so far
# Status Code: 200
# Total Records So Far: 550
# Retrieved 550 records so far
# Status Code: 200
# Total Records So Far: 575
# Retrieved 575 records so far
# Status Code: 200
# Total Records So Far: 600
# Retrieved 600 records so far
# Status Code: 200
# Total Records So Far: 625
# Retrieved 625 records so far
# Status Code: 200
# Total Records So Far: 650
# Retrieved 650 records so far
# Status Code: 200
# Total Records So Far: 675
# Retrieved 675 records so far
# Status Code: 200
# Total Records So Far: 700
# Retrieved 700 records so far
# Status Code: 200
# Total Records So Far: 725
# Retrieved 725 records so far
# Status Code: 200
# Total Records So Far: 750
# Retrieved 750 records so far
# Status Code: 200
# Total Records So Far: 775
# Retrieved 775 records so far
# Status Code: 200
# Total Records So Far: 800
# Retrieved 800 records so far
# Status Code: 200
# Total Records So Far: 825
# Retrieved 825 records so far
# Status Code: 200
# Total Records So Far: 850
# Retrieved 850 records so far
# Status Code: 200
# Total Records So Far: 875
# Retrieved 875 records so far
# Status Code: 200
# Total Records So Far: 900
# Retrieved 900 records so far
# Status Code: 200
# Total Records So Far: 925
# Retrieved 925 records so far
# Status Code: 200
# Total Records So Far: 950
# Retrieved 950 records so far
# Status Code: 200
# Total Records So Far: 975
# Retrieved 975 records so far
# Status Code: 200
# Total Records So Far: 1000
# Retrieved 1000 records so far
# Status Code: 200
# Total Records So Far: 1025
# Retrieved 1025 records so far
# Status Code: 200
# Total Records So Far: 1050
# Retrieved 1050 records so far
# Status Code: 200
# Total Records So Far: 1075
# Retrieved 1075 records so far
# Status Code: 200
# Total Records So Far: 1100
# Retrieved 1100 records so far
# Status Code: 200
# Total Records So Far: 1125
# Retrieved 1125 records so far
# Status Code: 200
# Total Records So Far: 1150
# Retrieved 1150 records so far
# Status Code: 200
# Total Records So Far: 1175
# Retrieved 1175 records so far
# Status Code: 200
# Total Records So Far: 1200
# Retrieved 1200 records so far
# Status Code: 200
# Total Records So Far: 1225
# Retrieved 1225 records so far
# Status Code: 200
# Total Records So Far: 1250
# Retrieved 1250 records so far
# Status Code: 200
# Total Records So Far: 1275
# Retrieved 1275 records so far
# Status Code: 200
# Total Records So Far: 1300
# Retrieved 1300 records so far
# Status Code: 200
# Total Records So Far: 1325
# Retrieved 1325 records so far
# Status Code: 200
# Total Records So Far: 1350
# Retrieved 1350 records so far
# Status Code: 200
# Total Records So Far: 1375
# Retrieved 1375 records so far
# Status Code: 200
# Total Records So Far: 1400
# Retrieved 1400 records so far
# Status Code: 200
# Total Records So Far: 1425
# Retrieved 1425 records so far
# Status Code: 200
# Total Records So Far: 1450
# Retrieved 1450 records so far
# Status Code: 200
# Total Records So Far: 1475
# Retrieved 1475 records so far
# Status Code: 200
# Total Records So Far: 1500
# Retrieved 1500 records so far
# Status Code: 200
# Total Records So Far: 1525
# Retrieved 1525 records so far
# Status Code: 200
# Total Records So Far: 1550
# Retrieved 1550 records so far
# Status Code: 200
# Total Records So Far: 1575
# Retrieved 1575 records so far
# Status Code: 200
# Total Records So Far: 1600
# Retrieved 1600 records so far
# Status Code: 200
# Total Records So Far: 1625
# Retrieved 1625 records so far
# Status Code: 200
# Total Records So Far: 1650
# Retrieved 1650 records so far
# Status Code: 200
# Total Records So Far: 1675
# Retrieved 1675 records so far
# Status Code: 200
# Total Records So Far: 1700
# Retrieved 1700 records so far
# Status Code: 200
# Total Records So Far: 1725
# Retrieved 1725 records so far
# Status Code: 200
# Total Records So Far: 1750
# Retrieved 1750 records so far
# Status Code: 200
# Total Records So Far: 1775
# Retrieved 1775 records so far
# Status Code: 200
# Total Records So Far: 1800
# Retrieved 1800 records so far
# Status Code: 200
# Total Records So Far: 1825
# Retrieved 1825 records so far
# Status Code: 200
# Total Records So Far: 1850
# Retrieved 1850 records so far
# Status Code: 200
# Total Records So Far: 1875
# Retrieved 1875 records so far
# Status Code: 200
# Total Records So Far: 1900
# Retrieved 1900 records so far
# Status Code: 200
# Total Records So Far: 1925
# Retrieved 1925 records so far
# Status Code: 200
# Total Records So Far: 1950
# Retrieved 1950 records so far
# Status Code: 200
# Total Records So Far: 1975
# Retrieved 1975 records so far
# Status Code: 200
# Total Records So Far: 2000
# Retrieved 2000 records so far
# Status Code: 200
# Total Records So Far: 2025
# Retrieved 2025 records so far
# Status Code: 200
# Total Records So Far: 2050
# Retrieved 2050 records so far
# Status Code: 200
# Total Records So Far: 2075
# Retrieved 2075 records so far
# Status Code: 200
# Total Records So Far: 2100
# Retrieved 2100 records so far
# Status Code: 200
# Total Records So Far: 2125
# Retrieved 2125 records so far
# Status Code: 200
# Total Records So Far: 2150
# Retrieved 2150 records so far
# Status Code: 200
# Total Records So Far: 2175
# Retrieved 2175 records so far
# Status Code: 200
# Total Records So Far: 2200
# Retrieved 2200 records so far
# Status Code: 200
# Total Records So Far: 2225
# Retrieved 2225 records so far
# Status Code: 200
# Total Records So Far: 2250
# Retrieved 2250 records so far
# Status Code: 200
# Total Records So Far: 2275
# Retrieved 2275 records so far
# Status Code: 200
# Total Records So Far: 2300
# Retrieved 2300 records so far
# Status Code: 200
# Total Records So Far: 2325
# Retrieved 2325 records so far
# Status Code: 200
# Total Records So Far: 2350
# Retrieved 2350 records so far
# Status Code: 200
# Total Records So Far: 2375
# Retrieved 2375 records so far
# Status Code: 200
# Total Records So Far: 2400
# Retrieved 2400 records so far
# Status Code: 200
# Total Records So Far: 2425
# Retrieved 2425 records so far
# Status Code: 200
# Total Records So Far: 2450
# Retrieved 2450 records so far
# Status Code: 200
# Total Records So Far: 2475
# Retrieved 2475 records so far
# Status Code: 200
# Total Records So Far: 2500
# Retrieved 2500 records so far
# Status Code: 200
# Total Records So Far: 2525
# Retrieved 2525 records so far
# Status Code: 200
# Total Records So Far: 2550
# Retrieved 2550 records so far
# Status Code: 200
# Total Records So Far: 2575
# Retrieved 2575 records so far
# Status Code: 200
# Total Records So Far: 2600
# Retrieved 2600 records so far
# Status Code: 200
# Total Records So Far: 2625
# Retrieved 2625 records so far
# Status Code: 200
# Total Records So Far: 2650
# Retrieved 2650 records so far
# Status Code: 200
# Total Records So Far: 2675
# Retrieved 2675 records so far
# Status Code: 200
# Total Records So Far: 2700
# Retrieved 2700 records so far
# Status Code: 200
# Total Records So Far: 2725
# Retrieved 2725 records so far
# Status Code: 200
# Total Records So Far: 2750
# Retrieved 2750 records so far
# Status Code: 200
# Total Records So Far: 2775
# Retrieved 2775 records so far
# Status Code: 200
# Total Records So Far: 2800
# Retrieved 2800 records so far
# Status Code: 200
# Total Records So Far: 2825
# Retrieved 2825 records so far
# Status Code: 200
# Total Records So Far: 2850
# Retrieved 2850 records so far
# Status Code: 200
# Total Records So Far: 2875
# Retrieved 2875 records so far
# Status Code: 200
# Total Records So Far: 2900
# Retrieved 2900 records so far
# Status Code: 200
# Total Records So Far: 2925
# Retrieved 2925 records so far
# Status Code: 200
# Total Records So Far: 2950
# Retrieved 2950 records so far
# Status Code: 200
# Total Records So Far: 2975
# Retrieved 2975 records so far
# Status Code: 200
# Total Records So Far: 3000
# Retrieved 3000 records so far
# Status Code: 200
# Total Records So Far: 3025
# Retrieved 3025 records so far
# Status Code: 200
# Total Records So Far: 3050
# Retrieved 3050 records so far
# Status Code: 200
# Total Records So Far: 3075
# Retrieved 3075 records so far
# Status Code: 200
# Total Records So Far: 3100
# Retrieved 3100 records so far
# Status Code: 200
# Total Records So Far: 3125
# Retrieved 3125 records so far
# Status Code: 200
# Total Records So Far: 3150
# Retrieved 3150 records so far
# Status Code: 200
# Total Records So Far: 3175
# Retrieved 3175 records so far
# Status Code: 200
# Total Records So Far: 3200
# Retrieved 3200 records so far
# Status Code: 200
# Total Records So Far: 3225
# Retrieved 3225 records so far
# Status Code: 200
# Total Records So Far: 3250
# Retrieved 3250 records so far
# Status Code: 200
# Total Records So Far: 3275
# Retrieved 3275 records so far
# Status Code: 200
# Total Records So Far: 3300
# Retrieved 3300 records so far
# Status Code: 200
# Total Records So Far: 3325
# Retrieved 3325 records so far
# Status Code: 200
# Total Records So Far: 3350
# Retrieved 3350 records so far
# Status Code: 200
# Total Records So Far: 3375
# Retrieved 3375 records so far
# Status Code: 200
# Total Records So Far: 3400
# Retrieved 3400 records so far
# Status Code: 200
# Total Records So Far: 3425
# Retrieved 3425 records so far
# Status Code: 200
# Total Records So Far: 3450
# Retrieved 3450 records so far
# Status Code: 200
# Total Records So Far: 3475
# Retrieved 3475 records so far
# Status Code: 200
# Total Records So Far: 3500
# Retrieved 3500 records so far
# Status Code: 200
# Total Records So Far: 3525
# Retrieved 3525 records so far
# Status Code: 200
# Total Records So Far: 3550
# Retrieved 3550 records so far
# Status Code: 200
# Total Records So Far: 3575
# Retrieved 3575 records so far
# Status Code: 200
# Total Records So Far: 3600
# Retrieved 3600 records so far
# Status Code: 200
# Total Records So Far: 3625
# Retrieved 3625 records so far
# Status Code: 200
# Total Records So Far: 3650
# Retrieved 3650 records so far
# Status Code: 200
# Total Records So Far: 3675
# Retrieved 3675 records so far
# Status Code: 200
# Total Records So Far: 3700
# Retrieved 3700 records so far
# Status Code: 200
# Total Records So Far: 3725
# Retrieved 3725 records so far
# Status Code: 200
# Total Records So Far: 3750
# Retrieved 3750 records so far
# Status Code: 200
# Total Records So Far: 3775
# Retrieved 3775 records so far
# Status Code: 200
# Total Records So Far: 3800
# Retrieved 3800 records so far
# Status Code: 200
# Total Records So Far: 3825
# Retrieved 3825 records so far
# Status Code: 200
# Total Records So Far: 3850
# Retrieved 3850 records so far
# Status Code: 200
# Total Records So Far: 3875
# Retrieved 3875 records so far
# Status Code: 200
# Total Records So Far: 3900
# Retrieved 3900 records so far
# Status Code: 200
# Total Records So Far: 3925
# Retrieved 3925 records so far
# Status Code: 200
# Total Records So Far: 3950
# Retrieved 3950 records so far
# Status Code: 200
# Total Records So Far: 3975
# Retrieved 3975 records so far
# Status Code: 200
# Total Records So Far: 4000
# Retrieved 4000 records so far
# Status Code: 200
# Total Records So Far: 4025
# Retrieved 4025 records so far
# Status Code: 200
# Total Records So Far: 4050
# Retrieved 4050 records so far
# Status Code: 200
# Total Records So Far: 4075
# Retrieved 4075 records so far
# Status Code: 200
# Total Records So Far: 4100
# Retrieved 4100 records so far
# Status Code: 200
# Total Records So Far: 4125
# Retrieved 4125 records so far
# Status Code: 200
# Total Records So Far: 4150
# Retrieved 4150 records so far
# Status Code: 200
# Total Records So Far: 4175
# Retrieved 4175 records so far
# Status Code: 200
# Total Records So Far: 4200
# Retrieved 4200 records so far
# Status Code: 200
# Total Records So Far: 4225
# Retrieved 4225 records so far
# Status Code: 200
# Total Records So Far: 4240
# Total records retrieved: 4240
# Data cached.
# df_membership shape is : (4240, 18)
